# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
habit_tracking = pd.read_csv('./data.csv')
habit_tracking.head(5)
# Out:
#    Progress                Day 👟 Run | Walk - 30 min ⚖️ Weigh Myself  \
# 0       NaN  @January 30, 2024                   Yes             Yes
# 1       NaN  @January 29, 2024                    No             Yes
# 2       NaN  @January 28, 2024                   Yes             Yes
# 3       NaN  @January 27, 2024                    No              No
# 4       NaN  @January 26, 2024                    No              No
#
#   ✉️ Clear Email 💊 Take pills 💪 Push Ups 😴 6 hours of sleep? 📱 Clear Texts  \
# 0             No          Yes        Yes                  No           Yes
# 1             No           No         No                  No            No
# 2            Yes          Yes        Yes                  No           Yes
# 3             No           No         No                  No            No
# 4             No           No         No                  No            No
#
#   🧼 Shower  ... 🏷️ Sell | Listero – 1 ticket | checkbox 💅🏻 Katie  \
# ...

# %%
# Remove "@" from `Day` and then convert the column to a workable date format

# Remove the `Progress` column

# Use a pivot table method to create completion percentage for each `Day` across all of the columns

# Plot the completion percentage by `Day`

# Target: If I improved both my happiness score and my habit tracking completion percentage for the month.
# Reward: I get to pull $500 from my personal Bitcoin holdings to spend on or save towards whatever I want :)

# One day I could do correlation analyses between my habit tracking binary data and my happiness score levels and/or my Google Analytics for www.jacoblyman.com key metrics.
